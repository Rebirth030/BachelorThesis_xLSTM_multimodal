# %%
# --- Imports ---
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, root_mean_squared_error, mean_squared_error

from src.data_prep import PrepAndDataLoader
from src.model_wrapper import Model, set_global_seed  # <- zeigt auf die oben gezeigte Datei

# %%
# %%
# --- Utils ---
def ensure_dir(path: str):
    os.makedirs(path, exist_ok=True)


def plot_history_from_json(history_json_path: str, title: str = ""):
    if not os.path.isfile(history_json_path):
        print(f"[WARN] History file not found: {history_json_path}")
        return
    with open(history_json_path, "r") as f:
        hist = json.load(f)

    plt.figure()
    if "loss" in hist:
        plt.plot(hist["loss"], label="train_loss")
    if "val_loss" in hist:
        plt.plot(hist["val_loss"], label="val_loss")
    plt.title(f"Training History {title}")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# %%
# --- Config laden ---
CONFIG = json.load(open("../../config.json"))
set_global_seed(CONFIG["random_seed"])

CSV_PATH = CONFIG["data"]["files"][0]
cols = CONFIG["data"]["columns"]
target_col = CONFIG["data"]["target_col"]

train_split = CONFIG["data"]["training_split"]
val_split = CONFIG["data"]["validation_split"]

WINDOW = int(CONFIG["data"]["window_size"])
H = int(CONFIG["data"]["horizons"][0])
NORMALISE = CONFIG["data"]["normalise"]
NORM_METHOD = CONFIG["data"]["norm_method"]
STRIDE = int(CONFIG["data"].get("stride", 1))

print("Using CSV:", CSV_PATH)
print(f"Window={WINDOW}, Horizon={H}, Norm={NORM_METHOD}, Columns={cols}")
# Out:
# KeyboardInterrupt
#
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x000002AF00F1D6A0>>
# Traceback (most recent call last):
#   File "C:\Users\juli\anaconda3\envs\BachelorThesis\Lib\site-packages\ipykernel\ipkernel.py", line 796, in _clean_thread_parent_frames
#     active_threads = {thread.ident for thread in threading.enumerate()}
#   File "C:\Users\juli\anaconda3\envs\BachelorThesis\Lib\threading.py", line 1479, in enumerate
#     def enumerate():
# KeyboardInterrupt:

# %%
# %%
# --- Daten vorbereiten ---
dl = PrepAndDataLoader(
    filename=CSV_PATH,
    training_split=train_split,
    validation_split=val_split,
    cols=cols,
    target_col=target_col,
    dtype="float32",
)

# Fenster bauen (paper-konform: Horizon H direkt)
X_tr, y_tr, b_tr, bT_tr = dl.get_train_data(
    normalise=NORMALISE,
    window_size=WINDOW,
    prediction_range=H,
    norm_method=NORM_METHOD,
    stride=STRIDE,

)
X_va, y_va, b_va, bT_va = dl.get_validation_data(
    normalise=NORMALISE,
    window_size=WINDOW,
    prediction_range=H,
    norm_method=NORM_METHOD,
    stride=STRIDE,
)
X_te, y_te, b_te, bT_te = dl.get_test_data(
    normalise=NORMALISE,
    window_size=WINDOW,
    prediction_range=H,
    norm_method=NORM_METHOD,
    stride=STRIDE,
)

dates_te = dl.get_prediction_dates(
    "test",
    window_size=WINDOW,
    prediction_range=H,
    stride=STRIDE,
)  # [N, H] of datetime-like values

print("Shapes ->",
      "X_train", X_tr.shape, "y_train", y_tr.shape,
      "| X_val", X_va.shape, "y_val", y_va.shape,
      "| X_test", X_te.shape, "y_test", y_te.shape)
# Out:
# Shapes -> X_train (2276, 60, 5) y_train (2276, 1, 1) | X_val (718, 60, 5) y_val (718, 1, 1) | X_test (720, 60, 5) y_test (720, 1, 1)

# %%
xlstm_cfg = {
    "window_size": CONFIG["data"]["window_size"],
    "n_features": len(CONFIG["data"]["columns"]),
    "horizon": H,
    "units": 128,
    "xlstm_num_blocks": 6,
    "xlstm_slstm_at": [],  #[[], [0], [1], [2], [3], [0,1], [1,2], [2,3]]
    "dropout": 0.1,
    "optimizer": "adamW",
    "learning_rate": 0.001740838159258218,
    "loss": CONFIG["data"]["loss"],

    "xlstm_mlstm_conv1d_kernel_size": 3,
    "xlstm_mlstm_qkv_proj_blocksize": 4,
    "xlstm_mlstm_num_heads": 2,
    "xlstm_mlstm_proj_factor": 1.5,

    "xlstm_slstm_conv1d_kernel": 3,
    "xlstm_slstm_num_heads": 2
}

model = Model()
model.build(
    config=xlstm_cfg,
    model_type="xLSTM",
)
print(f"[Device] Using device: {model.device}")
# Out:
# [Model] xLSTM compiled:
#   Input: seq_len=60, features=5 | hidden=128 | horizon=1
#   xLSTM blocks=6, sLSTM at=[]
#   Trainable params: 485,273
# [Device] Using device: cuda

# %%
# --- Training ---
train_cfg = CONFIG["training"]
save_dir = CONFIG["xLSTM_model"]["save_dir"]
ensure_dir(save_dir)

ckpt_path = model.train(
    X_tr, y_tr,
    X_va, y_va,
    epochs=int(train_cfg["epochs"]),
    batch_size=int(train_cfg["batch_size"]),
    save_dir=save_dir,
    patience=int(train_cfg["patience"]),
    monitor="val_loss",
    verbose=int(train_cfg["verbose"]),
    restore_best_weights=True,
)
print("Best checkpoint:", ckpt_path)
# Out:
# [Model] Training start | epochs=100 | batch_size=128 | horizon=1
# Epoch 001/100 - loss=0.396750 - val_loss=0.040301
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.040301)
# Epoch 002/100 - loss=0.028182 - val_loss=0.020613
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.020613)
# Epoch 003/100 - loss=0.017508 - val_loss=0.025100
# Epoch 004/100 - loss=0.014897 - val_loss=0.019765
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.019765)
# Epoch 005/100 - loss=0.012428 - val_loss=0.015395
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.015395)
# Epoch 006/100 - loss=0.009794 - val_loss=0.010308
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.010308)
# Epoch 007/100 - loss=0.007220 - val_loss=0.009407
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.009407)
# Epoch 008/100 - loss=0.006482 - val_loss=0.006752
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.006752)
# Epoch 009/100 - loss=0.004947 - val_loss=0.004343
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.004343)
# Epoch 010/100 - loss=0.004125 - val_loss=0.004139
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.004139)
# Epoch 011/100 - loss=0.003655 - val_loss=0.003186
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.003186)
# Epoch 012/100 - loss=0.003283 - val_loss=0.003784
# Epoch 013/100 - loss=0.002873 - val_loss=0.003236
# Epoch 014/100 - loss=0.002412 - val_loss=0.002316
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.002316)
# Epoch 015/100 - loss=0.002939 - val_loss=0.002533
# Epoch 016/100 - loss=0.002737 - val_loss=0.002379
# Epoch 017/100 - loss=0.002349 - val_loss=0.002220
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.002220)
# Epoch 018/100 - loss=0.001889 - val_loss=0.001838
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.001838)
# Epoch 019/100 - loss=0.001782 - val_loss=0.001773
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.001773)
# Epoch 020/100 - loss=0.001747 - val_loss=0.001926
# Epoch 021/100 - loss=0.001858 - val_loss=0.001993
# Epoch 022/100 - loss=0.001372 - val_loss=0.002035
# Epoch 023/100 - loss=0.001339 - val_loss=0.001403
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.001403)
# Epoch 024/100 - loss=0.001444 - val_loss=0.001556
# Epoch 025/100 - loss=0.001383 - val_loss=0.001299
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.001299)
# Epoch 026/100 - loss=0.001188 - val_loss=0.001227
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.001227)
# Epoch 027/100 - loss=0.001260 - val_loss=0.001863
# Epoch 028/100 - loss=0.001051 - val_loss=0.001313
# Epoch 029/100 - loss=0.001125 - val_loss=0.002899
# Epoch 030/100 - loss=0.001617 - val_loss=0.001217
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.001217)
# Epoch 031/100 - loss=0.001358 - val_loss=0.001487
# Epoch 032/100 - loss=0.001319 - val_loss=0.001777
# Epoch 033/100 - loss=0.001226 - val_loss=0.001301
# Epoch 034/100 - loss=0.000882 - val_loss=0.001135
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.001135)
# Epoch 035/100 - loss=0.000941 - val_loss=0.001610
# Epoch 036/100 - loss=0.000890 - val_loss=0.001116
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.001116)
# Epoch 037/100 - loss=0.001058 - val_loss=0.001486
# Epoch 038/100 - loss=0.001061 - val_loss=0.002054
# Epoch 039/100 - loss=0.001533 - val_loss=0.002000
# Epoch 040/100 - loss=0.000844 - val_loss=0.001011
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.001011)
# Epoch 041/100 - loss=0.000942 - val_loss=0.001288
# Epoch 042/100 - loss=0.001099 - val_loss=0.001123
# Epoch 043/100 - loss=0.001054 - val_loss=0.001391
# Epoch 044/100 - loss=0.000853 - val_loss=0.001458
# Epoch 045/100 - loss=0.000793 - val_loss=0.000958
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.000958)
# Epoch 046/100 - loss=0.000858 - val_loss=0.001101
# Epoch 047/100 - loss=0.000929 - val_loss=0.001859
# Epoch 048/100 - loss=0.001052 - val_loss=0.001227
# Epoch 049/100 - loss=0.000907 - val_loss=0.001032
# Epoch 050/100 - loss=0.000673 - val_loss=0.001080
# Epoch 051/100 - loss=0.000621 - val_loss=0.001002
# Epoch 052/100 - loss=0.000969 - val_loss=0.001592
# Epoch 053/100 - loss=0.000968 - val_loss=0.001169
# Epoch 054/100 - loss=0.000717 - val_loss=0.000865
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.000865)
# Epoch 055/100 - loss=0.000671 - val_loss=0.000934
# Epoch 056/100 - loss=0.000680 - val_loss=0.001173
# Epoch 057/100 - loss=0.000900 - val_loss=0.001520
# Epoch 058/100 - loss=0.001004 - val_loss=0.001331
# Epoch 059/100 - loss=0.000772 - val_loss=0.001806
# Epoch 060/100 - loss=0.000799 - val_loss=0.000837
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.000837)
# Epoch 061/100 - loss=0.000662 - val_loss=0.000860
# Epoch 062/100 - loss=0.000691 - val_loss=0.000954
# Epoch 063/100 - loss=0.000580 - val_loss=0.000857
# Epoch 064/100 - loss=0.000623 - val_loss=0.000871
# Epoch 065/100 - loss=0.000753 - val_loss=0.001063
# Epoch 066/100 - loss=0.000648 - val_loss=0.001290
# Epoch 067/100 - loss=0.000643 - val_loss=0.000814
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.000814)
# Epoch 068/100 - loss=0.000549 - val_loss=0.000806
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.000806)
# Epoch 069/100 - loss=0.000580 - val_loss=0.000819
# Epoch 070/100 - loss=0.000566 - val_loss=0.000776
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.000776)
# Epoch 071/100 - loss=0.000792 - val_loss=0.000984
# Epoch 072/100 - loss=0.001098 - val_loss=0.000871
# Epoch 073/100 - loss=0.001058 - val_loss=0.000935
# Epoch 074/100 - loss=0.000880 - val_loss=0.000879
# Epoch 075/100 - loss=0.000583 - val_loss=0.000830
# Epoch 076/100 - loss=0.000529 - val_loss=0.000940
# Epoch 077/100 - loss=0.000726 - val_loss=0.001184
# Epoch 078/100 - loss=0.000643 - val_loss=0.000750
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.000750)
# Epoch 079/100 - loss=0.000470 - val_loss=0.000766
# Epoch 080/100 - loss=0.000536 - val_loss=0.000786
# Epoch 081/100 - loss=0.000621 - val_loss=0.000852
# Epoch 082/100 - loss=0.000494 - val_loss=0.000734
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.000734)
# Epoch 083/100 - loss=0.000658 - val_loss=0.001095
# Epoch 084/100 - loss=0.000512 - val_loss=0.000889
# Epoch 085/100 - loss=0.000549 - val_loss=0.000793
# Epoch 086/100 - loss=0.000470 - val_loss=0.000868
# Epoch 087/100 - loss=0.000661 - val_loss=0.000914
# Epoch 088/100 - loss=0.000444 - val_loss=0.000725
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.000725)
# Epoch 089/100 - loss=0.000739 - val_loss=0.000881
# Epoch 090/100 - loss=0.000600 - val_loss=0.000813
# Epoch 091/100 - loss=0.000593 - val_loss=0.001292
# Epoch 092/100 - loss=0.000521 - val_loss=0.000877
# Epoch 093/100 - loss=0.000549 - val_loss=0.001158
# Epoch 094/100 - loss=0.000850 - val_loss=0.000824
# Epoch 095/100 - loss=0.000853 - val_loss=0.001464
# Epoch 096/100 - loss=0.000749 - val_loss=0.000754
# Epoch 097/100 - loss=0.000562 - val_loss=0.000783
# Epoch 098/100 - loss=0.000456 - val_loss=0.000692
# [Checkpoint] Saved best model to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt (val_loss=0.000692)
# Epoch 099/100 - loss=0.000583 - val_loss=0.001361
# Epoch 100/100 - loss=0.000974 - val_loss=0.000804
# [Model] Training finished: 134.02s
# [Model] Training history saved to: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100_history.json
# [Model] Best checkpoint: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt | best val_loss=0.000692
# [Model] Restored best weights into RAM.
# Best checkpoint: ./xlstm_checkpoints\xLSTM_H1_20251127-102902_b128_un128_layx_e100.pt

# %%
# --- History plot ---
history_json = ckpt_path.replace(".pt", "_history.json")
plot_history_from_json(history_json, title=f"H={H}, {os.path.basename(CSV_PATH)}")

# %%
# --- Test evaluation: RMSE & R² (scaled + denorm) ---

yhat_scaled = model.predict_multi_horizon(
    X_te,
    batch_size=int(train_cfg["batch_size"]),
    verbose=0,
)  # [N, H]

ytrue_scaled = y_te.squeeze(-1)    # [N, H]

rmse_scaled = root_mean_squared_error(ytrue_scaled, yhat_scaled)
r2_scaled   = r2_score(ytrue_scaled, yhat_scaled)

print(f"[TEST - SCALED] RMSE={rmse_scaled:.6f} | R2={r2_scaled:.6f}")


if NORMALISE:

    yhat_scaled_3d = yhat_scaled[..., None]  # [N, H, 1]
    ytrue_scaled_3d = y_te                   # [N, H, 1]

    if NORM_METHOD == "percentage":
        yhat_level = dl.denormalise(
            yhat_scaled_3d,
            method="percentage",
            base_values=bT_te,   # [N, 1]
            normalise=True,
        ).squeeze(-1)            # [N, H]

        ytrue_level = dl.denormalise(
            ytrue_scaled_3d,
            method="percentage",
            base_values=bT_te,
            normalise=True,
        ).squeeze(-1)

    elif NORM_METHOD == "minmax":
        yhat_level = dl.denormalise(
            yhat_scaled_3d,
            method="minmax",
            base_values=None,
            normalise=True,
        ).squeeze(-1)

        ytrue_level = dl.denormalise(
            ytrue_scaled_3d,
            method="minmax",
            base_values=None,
            normalise=True,
        ).squeeze(-1)

    else:
        raise ValueError(f"Unknown normalization method: {NORM_METHOD}")

    rmse_level = root_mean_squared_error(ytrue_level, yhat_level)
    r2_level   = r2_score(ytrue_level, yhat_level)

    print(f"[TEST - LEVEL] RMSE={rmse_level:.6f} | R2={r2_level:.6f}")

else:
    yhat_level  = yhat_scaled
    ytrue_level = ytrue_scaled

    print("[TEST] NORMALISE=False → scaled values are already in original scale.")
# Out:
# [TEST - SCALED] RMSE=0.019577 | R2=0.974386
# [TEST - LEVEL] RMSE=3.307589 | R2=0.988887

# %%
if STRIDE == 1:
    # ---------------------------------------------------------
    # Mode 1: stride=1 → show only last horizon t+H
    # ---------------------------------------------------------
    h_idx = H - 1  # last horizon index (t+H)

    dates_h = dates_te[:, h_idx]    # [N]
    true_h  = ytrue_level[:, h_idx] # [N]
    pred_h  = yhat_level[:, h_idx]  # [N]

    plt.figure(figsize=(12, 5))
    plt.plot(dates_h, true_h,  label=f"True (t+{H})")
    plt.plot(dates_h, pred_h, label=f"Pred (t+{H})")

    plt.title(f"{os.path.basename(CSV_PATH)} | Horizon = t+{H}")
    plt.xlabel("Date")
    plt.ylabel("Value")
    plt.legend()
    plt.grid(True)
    plt.gcf().autofmt_xdate()
    plt.show()

else:
    # ---------------------------------------------------------
    # Mode 2: stride > 1 → merge ALL horizons into one time series.
    # Example: H=15, stride=15: all t+1..t+15 become a single smooth line.
    # ---------------------------------------------------------
    dates_flat = dates_te.reshape(-1)
    true_flat  = ytrue_level.reshape(-1)
    pred_flat  = yhat_level.reshape(-1)

    df_plot = pd.DataFrame({
        "date": dates_flat,
        "true": true_flat,
        "pred": pred_flat,
    })

    # Average duplicate dates, sort chronologically
    df_plot = df_plot.groupby("date", as_index=True).mean().sort_index()

    plt.figure(figsize=(12, 5))
    plt.plot(df_plot.index, df_plot["true"], label="True (merged horizons)")
    plt.plot(df_plot.index, df_plot["pred"], label="Pred (merged horizons)")

    plt.title(f"{os.path.basename(CSV_PATH)} | H={H}, stride={STRIDE} (merged series)")
    plt.xlabel("Date")
    plt.ylabel("Value")
    plt.legend()
    plt.grid(True)
    plt.gcf().autofmt_xdate()
    plt.show()
